# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshrock7897/Artificial-Intelligence-Notes/blob/main/3_Advanced_Level.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##State-of-the-Art Models
# - GPT-3 and GPT-4
# - BERT and its variants (RoBERTa, DistilBERT, etc.)
# - T5 (Text-To-Text Transfer Transformer)
# - XLNet
# - BART (Bidirectional and Auto-Regressive Transformers)
#
# ##Advanced NLP Techniques
# - Transfer Learning in NLP
# - Zero-shot and few-shot learning
# - Multilingual NLP
# - Low-resource NLP
#
# ##Deep Learning for NLP
# - Advanced optimization techniques
# - Fine-tuning pre-trained models
# - Handling long sequences
#
# ##NLP in Production
# - Model deployment
# - Scalability and performance optimization
# - Monitoring and maintenance
#
# ##Research and Current Trends
# - Latest research papers and breakthroughs
# - Ethical considerations in NLP
# - Bias and fairness in NLP models
#
#
# ##Specialized Areas
# - Speech Recognition and Processing
# - Conversational AI and Chatbots
# - Sentiment Analysis and Emotion Detection
# - Information Retrieval and Search Engines
#
# ##Advanced NLP Pipelines
# - Designing complex NLP pipelines for large-scale applications
# - Customizing and optimizing pipelines for specific tasks
# - Integrating multiple NLP tasks in a single pipeline (e.g., NER + POS tagging + sentiment analysis)
# - Using and modifying advanced pipeline frameworks in production

# %% [markdown]
# # **State-of-the-Art Models**
#
# **GPT-3 and GPT-4**
# * Generative Pre-trained Transformers (GPT-3 and GPT-4) are state-of-the-art models developed by OpenAI for various NLP tasks like text generation, translation, and more.
#
# **Example (using OpenAI API):**

# %%
import openai

openai.api_key = 'your-api-key'

response = openai.Completion.create(
    engine="text-davinci-003",
    prompt="Translate the following English text to French: 'Hello, how are you?'",
    max_tokens=60
)

print(response.choices[0].text.strip())

# %% [markdown]
# # **BERT and its Variants**
# * BERT (Bidirectional Encoder Representations from Transformers) and its variants like RoBERTa, DistilBERT are designed for a range of NLP tasks such as question answering and text classification.
#
# **Example (using Hugging Face):**

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

inputs = tokenizer("Hello, how are you?", return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
print(logits)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# ...

# %% [markdown]
# **T5 (Text-To-Text Transfer Transformer)**
# * T5 treats every NLP problem as a text-to-text problem, making it highly flexible.
#
# **Example (using Hugging Face):**

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small')

input_text = "translate English to French: Hello, how are you?"
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ...

# %% [markdown]
# **XLNet**
# * XLNet is an autoregressive model that captures bidirectional context by maximizing the expected likelihood over all permutations of the input sequence.
#
# **Example:**

# %%
from transformers import XLNetTokenizer, XLNetModel

tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')
model = XLNetModel.from_pretrained('xlnet-base-cased')

inputs = tokenizer("Hello, how are you?", return_tensors="pt")
outputs = model(**inputs)
print(outputs.last_hidden_state)
# Out:
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# tensor([[[-0.6305, -2.8577, -1.8482,  ..., -0.3230, -1.6070, -0.5824],
#          [-0.9660, -3.9713, -0.5801,  ..., -1.1997, -2.8280, -1.3842],
#          [ 0.3945, -3.0315, -0.6769,  ..., -2.8164, -2.9639, -1.2445],
#          ...,
#          [ 0.9407, -1.2255, -1.6820,  ..., -2.3673,  1.0110, -1.6393],
#          [ 1.6478, -2.0922, -3.5904,  ..., -1.9416, -0.5616, -1.5112],
#          [ 1.5604, -2.4583, -3.4903,  ..., -1.3142, -1.0510, -1.3079]]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# **BART (Bidirectional and Auto-Regressive Transformers)**
# * BART is designed for sequence-to-sequence tasks like translation and text summarization.
#
# **Example:**

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large')

input_text = "Translate the following English text to French: Hello, how are you?"
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# Translate the following English text to French: Hello, how are you?

# %% [markdown]
# # **Advanced NLP Techniques**
#
# ** Transfer Learning in NLP**
# * Using pre-trained models and fine-tuning them on specific tasks.
#
# **Example:**

# %%
from transformers import BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader, TensorDataset # Import necessary modules for creating a DataLoader

# Sample data - replace this with your actual training data
inputs = torch.randint(0, 30522, (16, 128)) # Example input IDs
labels = torch.randint(0, 2, (16,)) # Example labels

# Create a DataLoader
train_dataset = TensorDataset(inputs, labels)
train_dataloader = DataLoader(train_dataset, batch_size=4) # Adjust batch size as needed

model = BertForSequenceClassification.from_pretrained('bert-base-uncased')
optimizer = AdamW(model.parameters(), lr=5e-5)

# Fine-tuning on a specific dataset
model.train()
for batch in train_dataloader:
    inputs = batch[0] # Access input_ids from the batch
    labels = batch[1] # Access labels from the batch
    outputs = model(inputs, labels=labels)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# **Zero-shot and Few-shot Learning**
# * Models are designed to perform tasks with little to no task-specific data.
#
# **Example:**

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
result = classifier("This is a great movie.", candidate_labels=["positive", "negative"])
print(result)
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'This is a great movie.', 'labels': ['positive', 'negative'], 'scores': [0.9960297346115112, 0.0039702365174889565]}

# %% [markdown]
# **Multilingual NLP**
# * Building models that support multiple languages.
#
# **Example:**

# %%
from transformers import MBartForConditionalGeneration, MBart50Tokenizer

tokenizer = MBart50Tokenizer.from_pretrained('facebook/mbart-large-50-many-to-one-mmt')
model = MBartForConditionalGeneration.from_pretrained('facebook/mbart-large-50-many-to-one-mmt')

input_text = "Hello, how are you?"
inputs = tokenizer(input_text, return_tensors="pt", src_lang="en_XX")
outputs = model.generate(**inputs, forced_bos_token_id=tokenizer.lang_code_to_id["fr_XX"])
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.51k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/268 [00:00<?, ?B/s]
# Keyword arguments {'src_lang': 'en_XX'} not recognized.
# Hello, how are you?

# %% [markdown]
# **Low-resource NLP**
# * Creating models that perform well on tasks with limited training data.
#
# **Example: Data augmentation techniques or using few-shot learning.**

# %% [markdown]
# # **Deep Learning for NLP**
#
# **Advanced Optimization Techniques**
# * Using techniques like learning rate scheduling, gradient clipping, etc., for better model training.
#
# **Example:**

# %%
from torch.optim.lr_scheduler import StepLR

# Define the number of epochs
num_epochs = 3  # Set this to the desired number of epochs

optimizer = AdamW(model.parameters(), lr=5e-5)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)

for epoch in range(num_epochs):
    for batch in train_dataloader:
        optimizer.step()
        scheduler.step()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# **Fine-tuning Pre-trained Models**
# * Fine-tuning pre-trained models on task-specific datasets.
#
# **Example: (Refer to Transfer Learning in NLP example above)**
#
# **Handling Long Sequences**
# * Techniques like truncation, hierarchical models, or models designed for long sequences like Longformer.
#
# **Example:**

# %%
from transformers import LongformerTokenizer, LongformerModel

tokenizer = LongformerTokenizer.from_pretrained('allenai/longformer-base-4096')
model = LongformerModel.from_pretrained('allenai/longformer-base-4096')

inputs = tokenizer("Hello, how are you?" * 500, return_tensors="pt", max_length=4096, truncation=True)
outputs = model(**inputs)
print(outputs.last_hidden_state)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Input ids are automatically padded to be a multiple of `config.attention_window`: 512
# tensor([[[-0.0376,  0.1458,  0.0065,  ..., -0.0336,  0.0305, -0.0778],
#          [-0.3337,  0.1943, -0.0288,  ...,  0.4500, -0.1309,  0.0676],
#          [-0.0249,  0.4944,  0.1073,  ...,  0.0323, -0.2719, -0.3880],
#          ...,
#          [ 0.0055,  0.4152,  0.1848,  ...,  0.0678, -0.1229,  0.0343],
#          [ 0.1883,  0.0071,  0.2994,  ..., -0.3159, -0.0608, -0.2043],
# ...

# %% [markdown]
# # **NLP in Production**
#
# **Model Deployment**
# * Deploying NLP models using services like AWS SageMaker, Azure ML, or custom solutions using Flask/Django.
#
# **Example:**

# %%
from flask import Flask, request, jsonify
import torch
from transformers import BertTokenizer, BertForSequenceClassification

app = Flask(__name__)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

@app.route('/predict', methods=['POST'])
def predict():
    text = request.json['text']
    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    prediction = torch.argmax(outputs.logits, dim=-1).item()
    return jsonify({'prediction': prediction})

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat

# %% [markdown]
# **Scalability and Performance Optimization**
# * Optimizing models for inference, using batch processing, and deploying on scalable infrastructure.
#
# **Monitoring and Maintenance**
# * Setting up monitoring for model performance, data drift, and retraining models as needed.

# %% [markdown]
# # **Research and Current Trends**
# * Latest Research Papers and Breakthroughs
# Staying updated with the latest papers from conferences like ACL, EMNLP, NeurIPS.
#
# **Ethical Considerations in NLP**
# * Addressing issues like bias, fairness, and transparency in NLP models.
#
# **Bias and Fairness in NLP Models**
# * Techniques to detect and mitigate bias in NLP models.
#
# # **Specialized Areas**
# **Speech Recognition and Processing**
# * Building and using models for converting speech to text.
#
# **Example (using Hugging Face):**

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer
import torchaudio

tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# Load an audio file
waveform, sample_rate = torchaudio.load("path_to_audio.wav")
inputs = tokenizer(waveform.squeeze().numpy(), return_tensors="pt", sampling_rate=sample_rate)
with torch.no_grad():
    logits = model(**inputs).logits
transcription = tokenizer.batch_decode(torch.argmax(logits, dim=-1))[0]
print(transcription)

# %% [markdown]
# **Conversational AI and Chatbots**
# * Building chatbots using frameworks like Rasa or using pre-trained models.
#
# **Example (using Hugging Face):**

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("microsoft/DialoGPT-medium")

input_text = "Hello, how are you?"
inputs = tokenizer.encode(input_text + tokenizer.eos_token, return_tensors="pt")
chat_history_ids = model.generate(inputs, max_length=1000, pad_token_id=tokenizer.eos_token_id)

output = tokenizer.decode(chat_history_ids[:, inputs.shape[-1]:][0], skip_special_tokens=True)
print(output)
# Out:
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# I'm good, how are you?

# %% [markdown]
# **Sentiment Analysis and Emotion Detection**
# * Building models to analyze sentiment and detect emotions in text.
#
# **Example:**

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
result = classifier("I love using transformers!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9994327425956726}]

# %% [markdown]
# **Information Retrieval and Search Engines**
# * Building systems to retrieve relevant information from large datasets.
#
# **Example:**

# %%
from transformers import DPRQuestionEncoder, DPRContextEncoder, DPRQuestionEncoderTokenizer, DPRContextEncoderTokenizer

question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained("facebook/dpr-question_encoder-single-nq-base")
context_tokenizer = DPRContextEncoderTokenizer.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base")

question_model = DPRQuestionEncoder.from_pretrained("facebook/dpr-question_encoder-single-nq-base")
context_model = DPRContextEncoder.from_pretrained("facebook/dpr-ctx_encoder-single-nq-base")

question = "What is the capital of France?"
context = "Paris is the capital of France."

question_inputs = question_tokenizer(question, return_tensors="pt")
context_inputs = context_tokenizer(context, return_tensors="pt")

question_embedding = question_model(**question_inputs).pooler_output
context_embedding = context_model(**context_inputs).pooler_output

print(question_embedding, context_embedding)

# %% [markdown]
# # **Advanced NLP Pipelines**
#
# **Designing Complex NLP Pipelines for Large-Scale Applications**
# * Combining multiple NLP tasks and ensuring scalability.
#
# **Customizing and Optimizing Pipelines for Specific Tasks**
# * Fine-tuning and adapting pipelines to specific domain requirements.
#
# **Integrating Multiple NLP Tasks in a Single Pipeline**
# * Combining tasks like NER, POS tagging, and sentiment analysis in a single workflow.
#
# **Example:**

# %%
import spacy
from transformers import pipeline

# Load SpaCy model
nlp_spacy = spacy.load("en_core_web_sm")

# Load Hugging Face sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis")

def process_text(text):
    # SpaCy NER and POS tagging
    doc = nlp_spacy(text)
    for ent in doc.ents:
        print(f"Entity: {ent.text}, Label: {ent.label_}")
    for token in doc:
        print(f"Token: {token.text}, POS: {token.pos_}")

    # Sentiment analysis
    sentiment = sentiment_analyzer(text)
    print(f"Sentiment: {sentiment}")

# Example text
text = "Apple is looking at buying U.K. startup for $1 billion."
process_text(text)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Entity: Apple, Label: ORG
# Entity: U.K., Label: GPE
# Entity: $1 billion, Label: MONEY
# Token: Apple, POS: PROPN
# Token: is, POS: AUX
# Token: looking, POS: VERB
# Token: at, POS: ADP
# Token: buying, POS: VERB
# Token: U.K., POS: PROPN
# Token: startup, POS: NOUN
# Token: for, POS: ADP
# Token: $, POS: SYM
# Token: 1, POS: NUM
# Token: billion, POS: NUM
# Token: ., POS: PUNCT
# ...
