# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshrock7897/Artificial-Intelligence-Notes/blob/main/1_NLP_Beginnner_Level.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Beginner Level Topics**
#
#
# ##Introduction to NLP
#
# - what is NLP ?
# - history of NLP
# - Advantage of NLP
# - Disadvantages of  NLP
# - Applications of NLP
# - Components of NLP
# - Libraries of NLP
# - NLP API’s
# - Phases of NLP
#
# ##Text Preprocessing
# - Tokenization
# - Stop words removal
# - Stemming and lemmatization
# - Text normalization (lowercasing, removing punctuation, etc.)
#
# ##Basic Linguistic Features
# - Part-of-Speech (POS) tagging
# - Named Entity Recognition (NER)
# - Chunking (Shallow Parsing)
#
# ##Basic Text Representations
# - Bag-of-Words (BoW)
# - Term Frequency-Inverse Document Frequency (TF-IDF)
# - One-hot encoding
#
# ##Basic Models and Algorithms
# - Naive Bayes
# - Logistic Regression
# - Simple Neural Networks
#
# ##Introduction to NLP Libraries
# - NLTK (Natural Language Toolkit)
# - SpaCy
# - Gensim

# %% [markdown]
# # **1. What is NLP?**
# * Natural Language Processing (NLP) is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language.
# * The goal of NLP is to enable computers to understand, interpret, and respond to human language in a way that is both meaningful and useful.
#
# # **2. History of NLP**
# * The history of NLP dates back to the 1950s and can be divided into several
# phases:
#
# * **1950s-1960s:** Early research was focused on rule-based systems and simple pattern matching. For example, ELIZA, developed by Joseph Weizenbaum, was an early chatbot that used pattern matching to simulate conversation.
#
# * **1970s-1980s:** The introduction of machine learning algorithms and statistical models began to shift the focus towards more data-driven approaches.
#
# * **1990s-2000s:** The rise of the internet and the availability of large text corpora facilitated the development of more sophisticated models.
#
# * **2010s-present:** The advent of deep learning and neural networks has revolutionized NLP, leading to the development of powerful models like BERT, GPT, and Transformer architectures.
#
#
# # **3. Advantages of NLP**
# * Automation: Automates repetitive tasks such as data entry and customer support.
# * Scalability: Can process large volumes of text data quickly and efficiently.
# * Accessibility: Makes technology accessible through voice commands and text interfaces.
# * Insights: Extracts valuable insights from unstructured text data.
#
#
# # **4. Disadvantages of NLP**
# * Complexity: Developing effective NLP systems can be complex and requires significant expertise.
# * Ambiguity: Natural language is often ambiguous and context-dependent, which can be challenging for NLP systems to handle.
# * Bias: NLP models can inherit biases present in the training data, leading to unfair or inaccurate outcomes.
# * Resource Intensive: Training large NLP models requires substantial computational resources.
#
# # **5. Applications of NLP**
# * Sentiment Analysis: Determining the sentiment behind a piece of text.
# Machine Translation: Translating text from one language to another.
# * Chatbots: Automating customer service interactions.
# * Text Summarization: Generating concise summaries of longer documents.
# * Named Entity Recognition (NER): Identifying entities like names, dates, and locations in text.
#
#
# # **6. Components of NLP**
# * Tokenization: Splitting text into individual words or tokens.
# * Part-of-Speech Tagging: Identifying the grammatical parts of speech in text.
# * Named Entity Recognition (NER): Detecting and classifying named entities.
# * Parsing: Analyzing the grammatical structure of sentences.
# * Semantic Analysis: Understanding the meaning of text.
#
#
# # **7. Libraries of NLP**
# * NLTK: Natural Language Toolkit, a comprehensive library for NLP in Python.
# * SpaCy: A fast and efficient NLP library with pre-trained models.
# * Gensim: A library for topic modeling and document similarity.
# * Hugging Face Transformers: A library for state-of-the-art transformer models.
# * Stanford NLP: A collection of NLP tools developed by Stanford University.
#
#
# # **8. NLP APIs**
# * Google Cloud Natural Language API: Provides pre-trained models for various NLP tasks.
# * Microsoft Azure Text Analytics API: Offers text analysis, including sentiment analysis and language detection.
# * IBM Watson Natural Language Understanding: Provides various NLP capabilities like entity extraction and sentiment analysis.
#
# # **9. Phases of NLP**
# * Text Preprocessing: Cleaning and preparing text data for analysis.
# * Tokenization: Splitting text into individual tokens.
# * Part-of-Speech Tagging: Assigning parts of speech to each token.
# * Named Entity Recognition (NER): Identifying and classifying named entities.
# * Parsing: Analyzing the grammatical structure of sentences.
# * Semantic Analysis: Extracting meaning from text.
# * Sentiment Analysis: Determining the sentiment behind text.
# * Machine Translation: Translating text from one language to another.
# * Text Summarization: Generating summaries of longer documents.
#
# **Example and Code**
# Let's go through an example demonstrating text preprocessing, tokenization, and part-of-speech tagging using SpaCy in Google Colab.

# %%
# Install SpaCy and download a model
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")

# Example text
text = "Apple is looking at buying U.K. startup for $1 billion"

# Process the text
doc = nlp(text)

# Tokenization
print("Tokens:")
for token in doc:
    print(token.text)

# Part-of-Speech Tagging
print("\nPart-of-Speech Tags:")
for token in doc:
    print(f"{token.text} - {token.pos_}")

# Named Entity Recognition
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Tokens:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion
#
# Part-of-Speech Tags:
# Apple - PROPN
# is - AUX
# looking - VERB
# at - ADP
# buying - VERB
# U.K. - PROPN
# startup - NOUN
# for - ADP
# $ - SYM
# 1 - NUM
# billion - NUM
#
# Named Entities:
# Apple - ORG
# U.K. - GPE
# $1 billion - MONEY
